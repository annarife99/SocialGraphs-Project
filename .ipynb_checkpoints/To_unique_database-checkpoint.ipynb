# %% [markdown]
# ## Compare CSV

# %%
#We import all the necessary packages
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import re
import urllib
import json
import urllib.request as urllib2

# %%
#All Data

Songs = pd.read_csv("AllAtributes.txt") 
DataSongs=pd.DataFrame(Songs)

Albums = pd.read_csv("AllAlbums.txt")
DataAlbums=pd.DataFrame(Albums)

AllSongs = pd.read_csv("Beatles_Dataset.csv")
DataAllSongs=pd.DataFrame(AllSongs)

# %%
DataSongs
# Out:
#                              Song  Year      Month  Day Lyrics  \
# 0                      Love_Me_Do  1962    October    5    Yes
# 1                   Ps_I_Love_You  1962    October    5    Yes
# 2                      Ask_Me_Why  1963    January   11    Yes
# 3                Please_Please_Me  1963    January   11     No
# 4                     Taste_Honey  1963      March   22     No
# ..                            ...   ...        ...  ...    ...
# 296              You_Know_What_Do  1995   November   20    Yes
# 297  You_Never_Give_Me_Your_Money  1969  September   26    Yes
# 298                Sie_Liebt_Dich  1964      March    5    Yes
# 299                     Slow_Down  1958      March    7     No
# 300               You_Me_Too_Much  1965     August    6    Yes
#
#                Writer  Album Genre
# 0    Lennon/McCartney    0.0   0.0
# 1           Not found    0.0   0.0
# 2    Lennon/McCartney    0.0   0.0
# 3           Not found    0.0   0.0
# 4           Not found    0.0   0.0
# ..                ...    ...   ...
# 296         Not found    0.0   0.0
# 297  Lennon/McCartney    0.0   0.0
# 298         Not found    0.0   0.0
# 299         Not found    0.0   0.0
# 300         Not found    0.0   0.0
#
# [301 rows x 8 columns]

# %%
DataAlbums
# Out:
#                                       Songs  \
# 0    Sgt. Pepper's Lonely Hearts Club Band
# 1        With a Little Help from My Friends
# 2             Lucy in the Sky with Diamonds
# 3                            Getting Better
# 4                             Fixing a Hole
# ..                                      ...
# 134                  And Your Bird Can Sing
# 135                     If I Needed Someone
# 136                      We Can Work It Out
# 137                            What Goes On
# 138                             Day Tripper
#
#                                    Album  Release Year
# 0    Sgt_Peppers_Lonely_Hearts_Club_Band          1967
# 1    Sgt_Peppers_Lonely_Hearts_Club_Band          1967
# 2    Sgt_Peppers_Lonely_Hearts_Club_Band          1967
# 3    Sgt_Peppers_Lonely_Hearts_Club_Band          1967
# 4    Sgt_Peppers_Lonely_Hearts_Club_Band          1967
# ..                                   ...           ...
# 134                  Yesterday_and_Today          1966
# 135                  Yesterday_and_Today          1966
# 136                  Yesterday_and_Today          1966
# 137                  Yesterday_and_Today          1966
# 138                  Yesterday_and_Today          1966
#
# [139 rows x 3 columns]

# %%
DataAllSongs
# Out:
#                                  Title  Year  \
# 0                      12-Bar Original  1965
# 1                    A Day in the Life  1967
# 2                   A Hard Day's Night  1964
# 3           A Shot of Rhythm and Blues  1963
# 4                     A Taste of Honey  1963
# ..                                 ...   ...
# 305     You're Going to Lose That Girl  1965
# 306  You've Got to Hide Your Love Away  1965
# 307     You've Really Got a Hold on Me  1963
# 308                        Young Blood  1963
# 309            Your Mother Should Know  1967
#
#                                            Album.debut  Duration  \
# 0                                          Anthology 2       174
# 1                Sgt. Pepper's Lonely Hearts Club Band       335
# 2                 UK: A Hard Day's Night US: 1962-1966       152
# 3                                      Live at the BBC       104
# 4           UK: Please Please Me US: The Early Beatles       163
# ..                                                 ...       ...
# 305                                              Help!       140
# 306                                              Help!       131
# 307  UK: With the Beatles US: The Beatles Second Album       182
# 308                                    Live at the BBC       116
# 309                               Magical Mystery Tour       149
#
#      Other.releases                                              Genre  \
# 0                 0                                              Blues
# 1                12               Psychedelic Rock, Art Rock, Pop/Rock
# 2                35                         Rock, Electronic, Pop/Rock
# 3                 0                                      R&B, Pop/Rock
# 4                29                       Pop/Rock, Jazz, Stage&Screen
# ..              ...                                                ...
# 305               6                                     Rock, Pop/Rock
# 306              12                                       FolkPop/Rock
# 307               2                                     Soul, Pop/Rock
# 308               0                                           Pop/Rock
# 309              13  Music Hall, Vaudeville Rock, Psychedelic Pop, ...
#
#                                   Songwriter              Lead.vocal  \
# 0    Lennon, McCartney, Harrison and Starkey                     NaN
# 1                       Lennon and McCartney    Lennon and McCartney
# 2                                     Lennon  Lennon, with McCartney
# 3                                   Thompson                  Lennon
# 4                              Scott, Marlow               McCartney
# ..                                       ...                     ...
# 305                                   Lennon                  Lennon
# 306                                   Lennon                  Lennon
# 307                                 Robinson     Lennon and Harrison
# 308                          Leiber, Stoller                Harrison
# 309                                McCartney               McCartney
#
#      Top.50.Billboard
# 0                  -1
# 1                  -1
# 2                   8
# 3                  -1
# 4                  -1
# ..                ...
# 305                -1
# 306                -1
# 307                -1
# 308                -1
# 309                -1
#
# [310 rows x 9 columns]
